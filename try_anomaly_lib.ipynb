# %%
# !git clone https://github.com/openvinotoolkit/anomalib.git
# Out:
# fatal: destination path 'anomalib' already exists and is not an empty directory.

# %%
# !pip install anomalib
# Out:
# ...
#   Using cached anomalib-0.3.6-py3-none-any.whl (248 kB)
# ...
#   Using cached wandb-0.12.17-py2.py3-none-any.whl (1.8 MB)
# ...
#   Using cached kornia-0.6.8-py2.py3-none-any.whl (551 kB)
# ...
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# ...
#   Using cached opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# ...
#   Using cached albumentations-1.3.0-py3-none-any.whl (123 kB)
# ...
#   Using cached omegaconf-2.2.3-py3-none-any.whl (79 kB)
# ...
#   Using cached pytorch_lightning-1.6.5-py3-none-any.whl (585 kB)
# ...
#   Using cached torchvision-0.12.0-cp310-cp310-win_amd64.whl (1.0 MB)
# ...
#   Using cached timm-0.5.4-py3-none-any.whl (431 kB)
# ...
#   Using cached torchtext-0.12.0-cp310-cp310-win_amd64.whl (1.5 MB)
# ...
#   Using cached einops-0.5.0-py3-none-any.whl (36 kB)
# ...
#   Using cached jsonargparse-4.15.1-py3-none-any.whl (158 kB)
# ...
#   Using cached torchmetrics-0.9.3-py3-none-any.whl (419 kB)
# ...
#   Using cached gradio-3.5-py3-none-any.whl (5.3 MB)
# ...
